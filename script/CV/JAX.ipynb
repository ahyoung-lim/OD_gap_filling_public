# %%
import os
from pathlib import Path
import importlib
import pymc as pm
import numpy as np
import pandas as pd
import xarray as xr
import arviz as az
from datetime import date
from scipy.special import gammaln
from sklearn.metrics import r2_score
import pyreadr
import pymc as pm
import pytensor
import pytensor.tensor as pt
from pytensor.scan.basic import scan
from pytensor import config as ptconfig
import pymc as pm
import pymc.sampling.jax as pmjax  # NEW
import jax

# %%
jax.config.update("jax_enable_x64", True)

# %%
#%cd ~/hamtoring_ubuntu
#%run Multi_model_CV_GPU_incidence_multi.py
#%run diag_hybrid_model.py

# %%
win_dir = Path("/mnt/c/Users/user/Dropbox/WORK/OpenDengue/OD_gap_filling_public")
os.chdir(win_dir)

# %%
# %run script/CV/03_down_DM_full_repeatedCV_v2.py
# Out:
# [rep 01] extrap_future | fold 1 | seed=123 | inla_down_mask_extrap_future_gzip_v2.rds
# sample: 100%|███████████████████████████████████████████████████████████████████████| 2500/2500 [07:42<00:00,  5.41it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# [rep 01] extrap_future | fold 2 | seed=123 | inla_down_mask_extrap_future_gzip_v2.rds
# sample: 100%|███████████████████████████████████████████████████████████████████████| 2500/2500 [07:49<00:00,  5.32it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# [rep 01] extrap_future | fold 3 | seed=123 | inla_down_mask_extrap_future_gzip_v2.rds
# sample: 100%|███████████████████████████████████████████████████████████████████████| 2500/2500 [07:40<00:00,  5.43it/s]
# ...

# %%
2+3

# %%
pkgs = ["pymc", "pytensor", "arviz", "jax", "numpy", "pandas", "xarray", "scipy", "sklearn"]

# %%
for p in pkgs:
    try:
        mod = importlib.import_module(p)
        print(f"{p}: {mod.__version__}")
    except Exception:
        print(f"{p}: NOT INSTALLED")
# Out:
# pymc: 5.25.1
# pytensor: 2.31.7
# arviz: 0.22.0
# jax: 0.7.0
# numpy: 2.3.2
# pandas: 2.3.1
# xarray: 2025.8.0
# scipy: 1.16.1
# sklearn: 1.7.1

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.12.3 (main, Jan 22 2026, 20:57:42) [GCC 13.3.0]
